# %% [markdown]
# # S34 ipynb markdown cell
# <img src=x onerror="document.title='FE_ipynb_md'">
# <script>document.title='FX_ipynb_md'</script>
# <svg onload="document.title='FS_ipynb_md'"></svg>
# [jslink](javascript:document.title='FJ_ipynb_md')

# %%
print('x')
# Out:
# <img src=x onerror="document.title='FE_ipynb_out'"><script>document.title='FX_ipynb_out'</script><svg onload="document.title='FS_ipynb_out'"></svg>
# x
# S34MARKER_ipynb_end
